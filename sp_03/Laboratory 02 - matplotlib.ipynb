# %% [markdown]
# # Script programming
#
# ## Laboratory 02 (matplotlib)
#
# ### Submission
#
# <u>Submission:</u>
#
# Compress all files into **single zip** archive and submit via Wikamp. See below the content of the archive (replace the `name` and `surname` with proper values):
# ```
# 📂 name.surname.zip
# +-- 📜 Laboratory 02 - matplotlib.ipynb
# ```
#
# <u>Grades</u>
#
# | Percentage of all points | mark |
# | :----                    | ---: |
# | [0-50)   | 2   |
# | [50-60)  | 3   |
# | [60-70)  | 3.5 |
# | [70-80)  | 4   |
# | [80-90)  | 4.5 |
# | [90-100] | 5   |
#
# <u>Penalties</u>
#
# * `mark - 0.5` if tasks are submitted after laboratory (but less than 7 days);
# * `mark - 1` if tasks are submitted after one week (>=7 days but < 14 days);
# * `mark - 1.5` if tasks are submitted later than two weeks (>=14 days).
#
# <u>Warning:</u>
#
# It is NOT allowed to share your `.ipynb` file with other students nor Internet. All students should download the exercise files directly from WIKAMP. Group work is considered as plagiarism.
#
# <u>Plagiarism Disclaimer:</u>
#
# I hereby declare that this exercise is my own and autonomous work. I am aware of the consequences and I am familiar with the university regulations.
#
#
# ### Task 1
#
# * Open a file `popular-names-in-poland.csv`,
# * and display a chart showing the number of children born (on Y axis) between 2000 and 2017 (on X axis).
# * Save the chart to file with `*.png` extension.
#
# **Tip**: You can read the file using below code:
#
# ```python
# np.recfromcsv("myfile.csv", encoding='iso-8859-2', delimiter = ...)
# ```
#
# Example:
# <img width="300" src="data:image/png;base64,..." />

# %%
# >>> WRITE YOUR CODE HERE <<<
import numpy as np
from matplotlib import *
f=np.recfromcsv("popular-names-in-poland.csv", encoding='iso-8859-2', delimiter =';')
print(f)

lata=np.unique(f.rok)

for i in len(lata)+1
    


#plot()
# Out:
# [(2000, 'JAKUB', 14497, 'M') (2000, 'MATEUSZ', 11454, 'M')
#  (2000, 'KACPER',  8898, 'M') ... (2017, 'VERONIKA',     5, 'K')
#  (2017, 'WIERA',     5, 'K') (2017, 'WIOLETA',     5, 'K')]

# %%
#notes
#f.imie
idx=np.where(f.imie=='JAKUB')
f[idx]
f[idx].liczba
np.sum(f[idx].liczba) #liczba Jakubów między 2000 a 2017
[x for x in range(2000,2018)]
np.unique(f.rok)
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017])

# %% [markdown]
# ### Task 2
#
# * Display a chart with a number of births between 2000 and 2017 for the 3 most popular boy names (3 series),
# * and the same for girls.
# * Both charts should be displayed as a single chart.
# * Save the chart to file with `*.png` extension.
#
# **Note**: Make sure you set the below details:
# * Colors: red, green, blue (for boys) and lime, maroon, silver (for girls).
# * Background color: snow.
# * All should be displayed as at the example below.
#
# Example:
# <img width="300" src="data:image/png;base64,..." />

# %%
# >>> WRITE YOUR CODE HERE <<<
#plus legend
#harder task
#both graphs in one png
#subplot()
