# %% [markdown]
# # Script programming (laboratory 10)
#
# ## PyQT
#
# ### Submission
#
# <u>Submission:</u>
#
# Compress all files into **single zip** archive and submit via Wikamp. See below the content of the archive (replace the `name` and `surname` with proper values):
# ```
# 📂 name.surname.zip
# +-- 📜 Labroatory 10 - PyQT.ipynb
#
# ```
#
# <u>Grades</u>
#
# | Number of points | mark |
# | :----            | ---: |
# | <5               | 2    |
# | 5                | 3    |
# | 6-7              | 3.5  |
# | 8                | 4    |
# | 9-10             | 4.5  |
# | 11               | 5    |
#
# <u>Penalties</u>
#
# * `mark - 0.5` if tasks are submitted next day (but less than 7 days);
# * `mark - 1` if tasks are submitted after one week (>=7 days but < 14 days);
# * `mark - 1.5` if tasks are submitted later than two weeks (>=14 days) but less than a month.
# * `mark = 2` if tasks are submitted a month after the laboratory (or does not at all).
#
# <u>Warning:</u>
#
# It is NOT allowed to share your `.ipynb` file with other students nor Internet. All students should download the exercise files directly from WIKAMP. Group work is considered as plagiarism.
#
# <u>Plagiarism Disclaimer:</u>
#
# I hereby declare that this exercise is my own and autonomous work. I am aware of the consequences and I am familiar with the university regulations.

# %% [markdown]
# ### Task 1. Create user interface
#
# Create GUI for calculator application.
#
# **NOTE: All the tasks can be done within jupyter notebook as well as separate *.py files.**
#
# <img style="height: 100pt" src="data:image/png;base64,..." />

# %%
import sys
from PyQt5.QtWidgets import *
from PyQt5.QtGui import *

# %%
import sys
from PyQt5.QtWidgets import (QWidget, QGridLayout,
                             QPushButton, QApplication)


class Example(QWidget):
    def __init__(self):
        super().__init__()
        self.init_ui()

    def init_ui(self):
        grid = QGridLayout()
        self.setLayout(grid)

        names = ['7', '8', '9', '/','',
                 '4', '5', '6', '*','C',
                 '1', '2', '3', '-',
                 '0', '.', '=', '+']

        positions = [(i,j) for i in range(5) for j in range(4)]

        for position, name in zip(positions, names):
            if name == '':
                continue
            btn = QPushButton(name)
            grid.addWidget(btn, *position)

        self.move(300,150)
        self.setWindowTitle('Calculator')
        self.show()


if __name__ == "__main__":
    app = QApplication(sys.argv)
    ex = Example()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# D:\Users\natyw\anaconda3\envs\ml\lib\site-packages\IPython\core\interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
class Calc(QMainWindow):
    def __init__(self):
        super(Calc, self).__init__()
        self.initUI()
        
        
    def initUI(self):
#         pos=[(0,0), (0,1)]
        
#         le = QLineEdit()
#         btn = QPushButton('Put')
#         grid=QGridLayout()
#         grid.addWidget(le,pos[0][0],pos[0][1])
#         grid.addWidget(btn,pos[1][0],pos[1][1])

        
#         self.setGeometry(300, 300, 290, 150)
#         self.setWindowTitle('Input dialog')
#         self.show()


        

#         self.setLayout(grid)
#         self.move(300,150)
#         self.statusBar().showMessage('Ready')
#         self.setWindowTitle('Calculator')
#         self.setGeometry(300,300,300,150)
#         self.setCentralWidget(None)
##
        grid = QGridLayout()
        self.setLayout(grid)

        names = ['Cls', 'Bck', '', 'Close',
                 '7', '8', '9', '/',
                 '4', '5', '6', '*',
                 '1', '2', '3', '-',
                 '0', '.', '=', '+']

        positions = [(i,j) for i in range(5) for j in range(4)]

        for position, name in zip(positions, names):
            if name == '':
                continue
            btn = QPushButton(name)
            grid.addWidget(btn, *position)

        self.move(300,150)
        self.setWindowTitle('Calculator')
        self.show()

    
def main():
    app=QApplication(sys.argv)
    ex=Calc()
    sys.exit(app.exec_())

if __name__ == '__main__':
    app = QApplication(sys.argv)
    ex = Calc()
    sys.exit(app.exec_())

# %%
pos=[(0,1), (1,0)]
print(pos[1][0], pos[1][1])
# Out:
# 1 0

# %%
#################################################################################
#################################notatki#########################################
#################################################################################

class Calc(QMainWindow):
    def __init__(self):
        super(Calc, self).__init__()
        self.initUI()
        

    def initUI(self):
        title = QLabel('Tytul')
        author = QLabel('Autor')
        review = QLabel('Recenzja')
        titleEdit = QLineEdit()
        authorEdit = QLineEdit()
        reviewEdit = QTextEdit()
        grid = QGridLayout()
        grid.setSpacing(10)
        grid.addWidget(title, 1, 0)
        grid.addWidget(titleEdit, 1, 1)
        grid.addWidget(author, 2, 0)
        grid.addWidget(authorEdit, 2, 1)
        grid.addWidget(review, 3, 0)
        grid.addWidget(reviewEdit, 3, 1, 5, 1)
        self.setLayout(grid) 
        self.setGeometry(300, 300, 350, 300)
        self.setWindowTitle('Recenzja')    
        self.show()






def main():
    app=QApplication(sys.argv)
    ex=Calc()
    sys.exit(app.exec_())

if __name__ == '__main__':
    main()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
        
        
        #buttons
        names=['Put','7','8','9','/','4','5','6','*','C','1','2','3','-','=','0','.','+']
        
        j=0
        pos=[(0,1),
             (1,0), (1,1), (1,2), (1,3), (1,4),
             (2,0),(2,1), (2,2), (2,3), (2,4), 
             (3,0),(3,1), (3,2), (3,3), (3,4),
             (4,0),(4,1), (4,3)]
        #pos=[(0,1),
        #     (1,0), (1,1), (1,2), (1,3),
        #     (2,0),(2,1), (2,2), (2,3), (2,4), 
        #     (3,0),(3,1), (3,2), (3,3), (3,4),
        #     (4,0),(4,1), (4,3)]
        
        for name in names:
            button=QPushButton(name)
            if j==2:
                grid.addWidget(QLabel(''), 0, 2)
            else:
                grid.addWidget(button, pos[j][0], pos[j][1])
            j=j+1

# %% [markdown]
# ### Task 2. Reverse Polish Notation
#
# Create a function which takes the list with parameters in Reverse Polish Notation (RPN) and returns the result.
#
# | Infix notation   | RPN |
# | :----            | ---:      |
# | 2 + 2            | 2 2 +     |
# | (1 + 2) / 3      | 1 2 + 3 / |
# | 1 + 2 / 3        | 1 2 3 / + |

# %%
def RPN(li):
    stack=list()
    for i in li:
        stack.append(i)
    RPN_digit=list()
    RPN_operation=list()

    operations={
        '+':lambda num1, num2: num1+num2,
        '*':lambda num1, num2: num1*num2,
        '-':lambda num1, num2: num1-num2,
        '/':lambda num1, num2: num1/num2}

    for j in range(len(stack)):
        el=stack.pop()
        if el in operations.keys():
            RPN_operation.insert(0,el)
        else:
            RPN_digit.insert(0,el)
    return RPN_digit+RPN_operation

# %%
print(RPN([2,'+',3,'-',7]))
# Out:
# [2, 3, 7, '+', '-']

# %%
#####notatki#######

# %%
stack=list()
stack.append(1)
stack.append(2)
stack.append(3)
stack.append(4)

# %%
stack
# Out:
# [1, 2, 3, 4]

# %%
el=stack.pop()

# %%
el
# Out:
# 4

# %%
stack
# Out:
# [1, 2, 3]

# %%
operations={
    '+':lambda num1, num2: num1+num2
}

# %%
stack=[1,4,'+']#dictionary with operators and values

# %%
el=stack.pop()

# %%
el
# Out:
# '+'

# %%
num1=stack.pop()

# %%
num1
# Out:
# 4

# %%
num2=stack.pop()

# %%
operations[el](num1,num2)
# Out:
# 5

# %%
#for loop to read operations and numbers
el in operations.keys() ##if true, then operation, else number

# %% [markdown]
# ### Task 3. RPN calculator with user interface
#
# Create RPN calculator with user interface create in PyQT.
#
# <img src="data:image/gif;base64,..." style="height:100pt" />

# %%
# >>> WRITE YOUR SOLUTION HERE <<<

# %%
def clearDisplay(self):
    """Clear the display."""
    self.setDisplayText('')

# %%
operator=['*',"+","/","-"]

def operation(o,a,b):
    if o=="+":
        result=a+b
    if o=="-":
        result=a-b
    if o=="*":
        result=a*b
    if o=="/":
        result=a/b
    return result

# %%
def count(expression):
    tokens = expression.split() #jeśli będzie string
    stack = []

    for token in tokens:
    if token in ops:
        arg2 = stack.pop()
        arg1 = stack.pop()
        result = ops[token](arg1, arg2)
        stack.append(result)
    else:
        stack.append(int(token))

    return stack.pop()
